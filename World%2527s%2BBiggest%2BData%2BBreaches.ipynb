# %% [markdown]
# Import the important Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Data Set Source: https://docs.google.com/spreadsheets/d/1Je-YUdnhjQJO_13r8iTeRxpU2pBKuV6RVRHoYCgiMfg/edit#gid=322165570

# %% [markdown]
# Data Set: This data source  is called Information is Beautiful and is taken from http://www.informationisbeautiful.net/.
# About the Data:
#  This data indicates the  security breaches that have been happening from 2004 to 2017, giving all the details such as records lost,
# entity, type of organzation, type of hacks and much more.

# %% [markdown]
# Upload the csv file

# %%
df = pd.read_csv('/Users/rosenrot/Downloads/Information.csv')

# %% [markdown]
# View  the csv Data

# %%
df.head()
# Out:
#                   Unnamed: 0  \
# 0                     Entity
# 1                        NaN
# 2                        AOL
# 3  Automatic Data Processing
# 4            Ameritrade Inc.
#
#                                           Unnamed: 1  \
# 0                                   alternative name
# 1                                                NaN
# 2                                    American Online
# 3           Business outsourcing, payrolls, benefits
# 4  Computer backup tape containing personal infor...
#
#                                           Unnamed: 2  \
# 0                                              story
# 1  Elaboration if there's an interesting story or...
# 2  A former America Online software engineer stol...
# 3                                                NaN
# 4                                      online broker
#
#                                           Unnamed: 3  \
# 0                                               YEAR
# ...

# %% [markdown]
# Drop the colums that are not required

# %%
df.drop(['Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17'], axis =1,inplace=True)

# %% [markdown]
# View the columns again

# %% [markdown]
# View the index

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %% [markdown]
# Rename the columns

# %%
Column_Names=df.iloc[0].values.tolist()
df.columns=Column_Names
df.head()
# Out:
#                       Entity  \
# 0                     Entity
# 1                        NaN
# 2                        AOL
# 3  Automatic Data Processing
# 4            Ameritrade Inc.
#
#                                     alternative name  \
# 0                                   alternative name
# 1                                                NaN
# 2                                    American Online
# 3           Business outsourcing, payrolls, benefits
# 4  Computer backup tape containing personal infor...
#
#                                                story  \
# 0                                              story
# 1  Elaboration if there's an interesting story or...
# 2  A former America Online software engineer stol...
# 3                                                NaN
# 4                                      online broker
#
#                                                 YEAR  \
# 0                                               YEAR
# ...

# %% [markdown]
# Make the location 0 as the main index

# %%
df.iloc[0].drop
# Out:
# <bound method NDFrame.drop of Entity                                Entity
# alternative name            alternative name
# story                                  story
# YEAR                                    YEAR
# records lost                    records lost
# ORGANISATION                    ORGANISATION
# METHOD OF LEAK                METHOD OF LEAK
# interesting story          interesting story
# NO OF RECORDS STOLEN    NO OF RECORDS STOLEN
# DATA SENSITIVITY            DATA SENSITIVITY
# Name: 0, dtype: object>

# %%
df.drop(0,inplace=True)

# %%
df['alternative name'].isnull().count()
# Out:
# 254

# %%
len(np.where(df['alternative name'].isnull())[0])
# Out:
# 136

# %%
len(np.where(df['story'].isnull())[0])
# Out:
# 36

# %%
len(np.where(df['YEAR'].isnull())[0])
# Out:
# 0

# %%
len(np.where(df['records lost'].isnull())[0])
# Out:
# 2

# %%
np.where(df['records lost'].isnull())[0]
# Out:
# array([147, 163])

# %%
df.drop(1,inplace=True)

# %%
df
# Out:
#                                              Entity  \
# 2                                               AOL
# 3                         Automatic Data Processing
# 4                                   Ameritrade Inc.
# 5                                         Citigroup
# 6                       Cardsystems Solutions Inc.
# 7                                   Hewlett Packard
# 8                        Countrywide Financial Corp
# 9                                              KDDI
# 10                       T-Mobile, Deutsche Telecom
# 11                                              AOL
# 12                           US Dept of Vet Affairs
# 13                                    Texas Lottery
# 14     City and Hackney Teaching Primary Care Trust
# 15                                          Gap Inc
# 16                                     Compass Bank
# 17                                      Monster.com
# 18                         Driving Standards Agency
# ...

# %% [markdown]
# Change the year to actual years

# %%
df.loc[df['YEAR'] =='0', 'YEAR'] = 2004
df.loc[df['YEAR'] =='1', 'YEAR'] = 2005
df.loc[df['YEAR'] =='2', 'YEAR'] = 2006
df.loc[df['YEAR'] =='3', 'YEAR'] = 2007
df.loc[df['YEAR'] =='4', 'YEAR'] = 2008
df.loc[df['YEAR'] =='5', 'YEAR'] = 2009
df.loc[df['YEAR'] =='6', 'YEAR'] = 2010
df.loc[df['YEAR'] =='7', 'YEAR'] = 2011
df.loc[df['YEAR'] =='8', 'YEAR'] = 2012
df.loc[df['YEAR'] =='9', 'YEAR'] = 2013
df.loc[df['YEAR'] =='10', 'YEAR'] = 2014
df.loc[df['YEAR'] =='11', 'YEAR'] = 2015
df.loc[df['YEAR'] =='12', 'YEAR'] = 2016
df.loc[df['YEAR'] =='13', 'YEAR'] = 2017
df.loc[df['YEAR'] =='14', 'YEAR'] = 2017

# %%
np.where(df['records lost'].isnull())[0]
# Out:
# array([146, 162])

# %%
np.where(df['records lost'].isnull())[0]
# Out:
# array([146, 162])

# %%
len(np.where(df['ORGANISATION'].isnull())[0])
# Out:
# 0

# %%
len(np.where(df['METHOD OF LEAK'].isnull())[0])
# Out:
# 0

# %%
df.drop(['interesting story'], axis =1,inplace=True)

# %%
df.columns
# Out:
# Index(['Entity', 'alternative name', 'story', 'YEAR', 'records lost',
#        'ORGANISATION', 'METHOD OF LEAK', 'NO OF RECORDS STOLEN',
#        'DATA SENSITIVITY'],
#       dtype='object')

# %%
len(np.where(df['DATA SENSITIVITY'].isnull())[0])
# Out:
# 0

# %%
len(np.where(df['story'].isnull())[0])
# Out:
# 36

# %%
df
# Out:
#                                              Entity  \
# 2                                               AOL
# 3                         Automatic Data Processing
# 4                                   Ameritrade Inc.
# 5                                         Citigroup
# 6                       Cardsystems Solutions Inc.
# 7                                   Hewlett Packard
# 8                        Countrywide Financial Corp
# 9                                              KDDI
# 10                       T-Mobile, Deutsche Telecom
# 11                                              AOL
# 12                           US Dept of Vet Affairs
# 13                                    Texas Lottery
# 14     City and Hackney Teaching Primary Care Trust
# 15                                          Gap Inc
# 16                                     Compass Bank
# 17                                      Monster.com
# 18                         Driving Standards Agency
# ...

# %% [markdown]
# #Delete the columns that are not required

# %%
df.drop(['alternative name'], axis =1,inplace=True)

# %%
df.drop(['story'], axis =1,inplace=True)

# %%
df.drop(['NO OF RECORDS STOLEN'], axis =1,inplace=True)

# %% [markdown]
# Update the Data Sensitivity Column according to the keywords for the numbers

# %%
df.loc[df['DATA SENSITIVITY'] =='1', 'DATA SENSITIVITY'] = 'Online information'
df.loc[df['DATA SENSITIVITY'] =='20', 'DATA SENSITIVITY'] = 'SSN'
df.loc[df['DATA SENSITIVITY'] =='300', 'DATA SENSITIVITY'] = 'Credit card information'
df.loc[df['DATA SENSITIVITY'] =='4000', 'DATA SENSITIVITY'] = 'Email password'
df.loc[df['DATA SENSITIVITY'] =='50000', 'DATA SENSITIVITY'] = 'Full bank account details'

# %% [markdown]
# Resetting the index

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# Finding out the missing data

# %%
np.where(df['DATA SENSITIVITY'].dtype==int)
# Out:
# (array([], dtype=int64),)

# %%
type(df['DATA SENSITIVITY'])
# Out:
# pandas.core.series.Series

# %%
np.unique(df['DATA SENSITIVITY'])
# Out:
# array(['3', 'Credit card information', 'Email password',
#        'Full bank account details', 'Online information', 'SSN'], dtype=object)

# %% [markdown]
# Adding information to the missing data

# %%
df.loc[df['DATA SENSITIVITY'] =='3', 'DATA SENSITIVITY'] = 'Persional information'

# %%
len(np.where(df['records lost'].isnull())[0])
# Out:
# 2

# %%
np.where(df['records lost'].isnull())[0]
# Out:
# array([146, 162])

# %%
df.iloc[146]
# Out:
# Entity                 OVH
# YEAR                  2013
# records lost           NaN
# ORGANISATION           web
# METHOD OF LEAK      hacked
# DATA SENSITIVITY       SSN
# Name: 146, dtype: object

# %% [markdown]
# Deleting the missing row in order

# %%
df=df.dropna()

# %%
df=df.rename(columns={'records lost': 'RECORDS LOST'})

# %%
df=df.rename(columns={'Entity': 'ENTITY'})

# %%
len(np.where(df['ORGANISATION'].isnull())[0])
# Out:
# 0

# %%
by_comp = df.groupby('ORGANISATION')
by_comp.min()
# Out:
#                                                    ENTITY  YEAR RECORDS LOST  \
# ORGANISATION
# academic                               Indiana University  2008       125000
# app                                              Snapchat  2017      1000000
# energy                      Central Hudson Gas & Electric  2008       110000
# financial                                 Ameritrade Inc.  2005      1000000
# gaming                              Bethesda Game Studios  2011      1290755
# government              Australian Immigration Department  2007       100000
# government, healthcare                           Medicaid  2009       780000
# government, military               US Dept of Vet Affairs  2006     26500000
# healthcare                         Accendo Insurance Co.   2009       100000
# legal                                     Mossack Fonseca  2016     11500000
# media                                       Sony Pictures  2011     10000000
# ...

# %%
by_comp.describe()
# Out:
#                        DATA SENSITIVITY                                    \
#                                   count unique                        top
# ORGANISATION
# academic                              9      3                        SSN
# app                                   2      2    Credit card information
# energy                                3      2                        SSN
# financial                            31      4    Credit card information
# gaming                                6      3                        SSN
# government                           37      5                        SSN
# government, healthcare                2      2                        SSN
# government, military                  1      1                        SSN
# healthcare                           36      5             Email password
# legal                                 1      1  Full bank account details
# ...

# %%
by_comp.describe().transpose()
# Out:
# ORGANISATION                                      academic  \
# DATA SENSITIVITY count                                   9
#                  unique                                  3
#                  top                                   SSN
#                  freq                                    6
# ENTITY           count                                   9
#                  unique                                  9
#                  top     University of California Berkeley
#                  freq                                    1
# METHOD OF LEAK   count                                   9
#                  unique                                  4
#                  top                                hacked
#                  freq                                    4
# RECORDS LOST     count                                   9
#                  unique                                  9
#                  top                                 73000
# ...

# %% [markdown]
# Imoprt the excel file

# %%
df.to_csv('/Users/rosenrot/Downloads/Information2.csv')

# %% [markdown]
# Tableau Link

# %% [markdown]
# https://public.tableau.com/profile/nishant.singh6271#!/vizhome/WorldsBiggestDataBreaches_9/Dashboard1?publish=yes

# %% [markdown]
# "Security breaches are becoming less severe ?"

# %% [markdown]
# No, according to me the security Breaches are becooming more severe

# %% [markdown]
# RoadMap:To make my case I have to have 4 major things I need which are,
# Year, frequency of incidents, Type of organization & Entity Names!!
#
# Audience: The audience is a Security team.
# Goals: Data to Decsion
# Questions: What's wrong? Who is getting hit the most ?

# %% [markdown]
# Link to the tableau Visualziation

# %% [markdown]
# https://public.tableau.com/views/SecurityBreachesbecomingmoresevere/Dashboard1?:embed=y&:display_count=yes

# %% [markdown]
# Version 1: Records Lost Vs Year
#
# https://public.tableau.com/profile/nishant.singh6271#!/vizhome/SecurityBreachesbecomingmoresevere/Sheet1
#
# Advantages: It represents total number of records lost per year to indicate that the records stolen due to
# security breaches over the years.
#
# Disadvantages: Inorder to understand the Visulaization and its objective it needs more information!!!!

# %% [markdown]
# Version 2: Non Tech. Vs Tech.
#
# https://public.tableau.com/profile/nishant.singh6271#!/vizhome/SecurityBreachesbecomingmoresevere/Sheet2
#
# Advantages: The graph here compares the  Tech firms & Non-tech firms and calculates the average data stolen between the two.
# Now the graph  clearly start telling us a story! Though the no of incidents are almost the same over the years but the
# amount of data loss is very high in Tech. firms!!!
#
# Disadvantages: Still to tell a story we need more details, something is still missing!!!

# %% [markdown]
# Final version: Security Breaches becoming more severe ?
# https://public.tableau.com/profile/nishant.singh6271#!/vizhome/SecurityBreachesbecomingmoresevere/Sheet3
#
# Advantage:
#
# This Visualization now is complete after adding data Sensitivity and Organization type. The senstivity of data is an indicator of how smart the hackers have become.Social security details are on a rise which could potentially have a tremendous impact on the people.The organization type indicates which types of organization are more vunerable and according to my analysis the compaines in the tech domain seem to be the victims of these hacks. The tech savy compaines should increase their security and allocate more funding to stop this.

# %% [markdown]
# Future Enhancements: If I had more time to go over this again I would definetely play with the data to generate more metrics
#     to better represent my visualization for taking an efective decision.
